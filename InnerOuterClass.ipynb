# %%
class car:
    def __init__(self):
        print("car created")
    class engine:
        def __init__(self):
            print("engine created")
    e=engine()
c=car()
# Out:
# engine created
# car created
