# %%
import importlib
import matho
importlib.reload(matho)
from matho import circle,rectangle
c=circle()
r=rectangle()
c.area(7)
c.perimeter()
r.area(l=10,b=6)
r.perimeter()
# Out:
# area of circle: 153.86
# perimeter of circle: 43.96
# area of rectangle: 60
# perimeter of rectangle: 32

# %%
import importlib
import MyPackage.details
importlib.reload(MyPackage.details)
from MyPackage.details import info
i=info()
i.show()
# Out:
# name: Prashant kumar singh
# age: 23
# college: Amity University Patna

# %%
from MyPackage.matho import circle,rectangle
a=circle()
b=rectangle()
a.area(r=14)
a.perimeter()
b.area(l=10,b=5)
b.perimeter()
# Out:
# area of circle: 615.44
# perimeter of circle: 87.92
# area of rectangle: 50
# perimeter of rectangle: 30
