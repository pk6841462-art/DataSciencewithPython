# %%
print("hello student")
name="prashant"
age=23
college=("amity university")
marks=74.6
print("NAME:",name)
print("AGE:",age)
print("COLLEGE:",college)
print("MARKS:",marks)
print("thank you student")

print(type(name))
print(type(age))
print(type(marks))
# Out:
# hello student
# NAME: prashant
# AGE: 23
# COLLEGE: amity university
# MARKS: 74.6
# thank you student
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a=10
b=7
sum=a+b
diff=a-b
mult=a*b
div=a/b
rem=a%b
print(div)
print(rem)
# Out:
# 1.4285714285714286
# 3

# %%
name=input ("enter your name:")
age=int(input("enter your age:"))
print("WELCOME ",name)
print("YOU ARE ",age," YEARS OLD NOW")
print(type(age))
# Out:
# enter your name: PRASHANT KUMAR SINGH
# enter your age: 23
# WELCOME  PRASHANT KUMAR SINGH
# YOU ARE  23  YEARS OLD NOW
# <class 'int'>

# %%
a=float(input("enter first number:"))
b=float(input("enter second number:"))
sum=a+b
print("sum of two numbers:",sum)
# Out:
# enter first number: 45.34
# enter second number: 324
# sum of two numbers: 369.34000000000003

# %%
side=int(input("enter side of the square:"))
area=side*side
perimeter=4*side
print("area:",area,"perimeter:",perimeter)
# Out:
# enter side of the square: 6
# area: 36 perimeter: 24
