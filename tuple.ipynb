# %%
tuple=(1,1,2,3,4,5,5,6,7)
print(tuple)
# Out:
# (1, 1, 2, 3, 4, 5, 5, 6, 7)

# %%
print(tuple[2])
print(tuple[3])
# Out:
# 2
# 3

# %%
print("no. of times elements occured",tuple.count(1))
print(tuple.index(5))
# Out:
# no. of times elements occured 2
# 5

# %%
a=(1,2,3)
b=(4,5)
t=a+b
print(t)
# Out:
# (1, 2, 3, 4, 5)
