# %%
class student:
    def __init__(self,name=None,age=None):
        self.name=name
        self.age=age
        print(self.name)
        print(self.age)
print("first object")
obj=student()
print("second object")
obj1=student("prashant")
print("third object")
obj2=student("raja",23)
# Out:
# first object
# None
# None
# second object
# prashant
# None
# third object
# raja
# 23
