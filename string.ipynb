# %%
str1='prashant"\nkaise ho bhai'
print(str1)
print(len(str1));
# Out:
# prashant"
# kaise ho bhai
# 23

# %%
a="shan"
b="tanu"
c=(a+b)
d="prashant"
print(len(d))
print(c)
print(len(c))
# Out:
# 8
# shantanu
# 8

# %%
college="prashant"

print(college.replace("a","aa"))
print(college.count("a"))
print(college.upper())
print(college.lower())
# Out:
# praashaant
# 2
# PRASHANT
# prashant

# %%
name=str(input("enter your name:"))
print("your name: ",name)
print("name's length: ",len(name))

print(name.find("r"))
print(name.count("a"))
# Out:
# enter your name: prashant
# your name:  prashant
# name's length:  8
# 1
# 2
