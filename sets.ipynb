# %%
s={1,2,3,4}
s1={3,4,5,6}
print("union",s|s1)
print("intersection",s&s1)
print("difference",s-s1)
simdiff=s.symmetric_difference(s1)
print(simdiff)
# Out:
# union {1, 2, 3, 4, 5, 6}
# intersection {3, 4}
# difference {1, 2}
# {1, 2, 5, 6}

# %%
a={1,2,3,7,8}
print(a)
a.clear()
print(a)
# Out:
# {1, 2, 3, 7, 8}
# set()

# %%
a = input()
b = a.split()

l = []

for i in b:
    l.append(int(i))

print(l)
# Out:
#  3
# [3]

# %% [markdown]
#  l=list(map(int,input().split()))
# for i in l:
#     if i%2==0:
#         print(i)
